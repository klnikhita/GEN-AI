# %% [markdown]
# <a href="https://colab.research.google.com/github/klnikhita/GEN-AI/blob/main/PDF%2BText_Summarizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # `**Gen AI Project (PDF and Text Summarizer)**`

# %%
# !pip install pypdf transformers sentencepiece
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.6/326.6 kB 5.5 MB/s eta 0:00:00

# %%
from pypdf import PdfReader
from transformers import pipeline

# %%
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
def summarize_text(text):
    # BART works best with chunks <1024 tokens
    max_length = 1024
    chunks = [text[i:i+max_length] for i in range(0, len(text), max_length)]

    summaries = []
    for chunk in chunks:
        summary = summarizer(chunk, max_length=130, min_length=30, do_sample=False)[0]['summary_text']
        summaries.append(summary)

    return "\n".join(summaries)

# %%
text = input("Enter text to summarize: ")

print("\n--- Summary ---\n")
print(summarize_text(text))
# Out:
# Enter text to summarize: GITAM at Bengaluru Tech Summit 2025 | Showcasing NanoSensor Innovation   We are delighted to share that the Nanosensor Innovation Lab, MURTI Research Center, GITAM Bengaluru, will be showcasing its cutting-edge research and technologies at the Bengaluru Tech Summit 2025.  Stall No. S224, Hall 3 Bangalore International Exhibition Centre, Tumkur Road, Bengaluru November 18–20, 2025  Our team will present innovations aimed at translating advanced nanomaterials into affordable, miniaturized, and high-performance sensor technologies — enabling real-world impact across healthcare, agriculture, and environmental monitoring.  These developments are part of our commitment to moving from bulky benchtop systems to portable, smart, and user-friendly devices, shaping the future of sensing technology.  We invite you to visit our stall and experience how GITAM is contributing to the future of science, technology, and innovation.  hashtag#GITAM hashtag#BTS2025 hashtag#Nanose
# ...

# %%
'''
from google.colab import files

uploaded = files.upload()
file_name = list(uploaded.keys())[0]

reader = PdfReader(file_name)
pdf_text = ""

for page in reader.pages:
    pdf_text += page.extract_text()

print("PDF Loaded. Summarizing...")
summary = summarize_text(pdf_text)

print("\n--- PDF Summary ---\n")
print(summary)
'''

# %%
from pypdf import PdfReader

file_path = "/content/Sai_Joshitha_Resume.pdf"

reader = PdfReader(file_path)
pdf_text = ""

for page in reader.pages:
    text = page.extract_text()
    if text:
        pdf_text += text

print("PDF Loaded. Summarizing...")
summary = summarize_text(pdf_text)

print("\n--- PDF Summary ---\n")
print(summary)
# Out:
# PDF Loaded. Summarizing...
# Your max_length is set to 130, but your input_length is only 98. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# --- PDF Summary ---
#
# A motivated and detail-oriented Computer Science Engineering student with strong analytical and communication skills. Eager to gainhands-on experience in a professional environment, contribute to team projects, and enhance technical and interpersonal skills.
# Quiz Game Application (Python Project) Jan 2023 – Mar 2023Developed a Python program that conducts a multiple-choice quiz for general knowledge questions. Implemented score tracking and feedback for correct and incorrect answers. Strengthened understanding of loops, conditional statements, and user input handling.
# ...

# %%
from pypdf import PdfReader

file_path = "/content/ai_pedagogy.pdf"

reader = PdfReader(file_path)
pdf_text = ""

for page in reader.pages:
    text = page.extract_text()
    if text:
        pdf_text += text

print("PDF Loaded. Summarizing...")
summary = summarize_text(pdf_text)

print("\n--- PDF Summary ---\n")
print(summary)
# Out:
# PDF Loaded. Summarizing...
# Your max_length is set to 130, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# --- PDF Summary ---
#
# The increasing demand for skilled professionals in Artificial Intelligence (AI) within the Fourth Industrial Rev-olution (4IR) has led to the establishment of AI courses in universities worldwide. Grounded theory methodology was employed, resulting in the development of five thematic categories.
# The findings highlight the importance of these pedagogical approaches in enhancing students’ learning. The study ’ s implications include informing the design of professional development programs for AI teachers.
# ...
